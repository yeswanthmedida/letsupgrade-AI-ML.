# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Vivek.M/Documents/AIML/Day 23/general_data.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# 2                 1.0      Y                15              8
# 3                 3.0      Y                11              8
# 4                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %% [markdown]
# # Dropping irrelevant columns

# %%
data1=data.drop(['EmployeeCount','EmployeeID','Over18','StandardHours'],axis=1)
data1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  Gender  JobLevel                    JobRole  \
# 0          2  Life Sciences  Female         1  Healthcare Representative
# 1          1  Life Sciences  Female         1         Research Scientist
# 2          4          Other    Male         4            Sales Executive
# 3          5  Life Sciences    Male         3            Human Resources
# 4          1        Medical    Male         1            Sales Executive
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 0       Married         131160                 1.0                 11
# 1        Single          41890                 0.0                 23
# 2       Married         193280                 1.0                 15
# 3       Married          83210                 3.0                 11
# 4        Single          23420                 4.0                 12
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0                1.0                      6               1
# 1                 1                6.0                      3               5
# 2                 3                5.0                      2               5
# 3                 3               13.0                      5               8
# 4                 2                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4

# %% [markdown]
# # Check for null values

# %%
data1.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # Filling the null values

# %%
data2=data1.fillna(data1.mean())
data2.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# # Encoding categorical attributes

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
data2['Attrition']=encoder.fit_transform(data1['Attrition'])

# %%
data2['BusinessTravel']=encoder.fit_transform(data1['BusinessTravel'])

# %%
data2['Department']=encoder.fit_transform(data1['Department'])

# %%
data2['EducationField']=encoder.fit_transform(data1['EducationField'])

# %%
data2['Gender']=encoder.fit_transform(data1['Gender'])

# %%
data2['JobRole']=encoder.fit_transform(data1['JobRole'])

# %%
data2['MaritalStatus']=encoder.fit_transform(data1['MaritalStatus'])

# %%
data2.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               2           2                 6          2
# 1   31          1               1           1                10          1
# 2   32          0               1           1                17          4
# 3   38          0               0           1                 2          5
# 4   32          0               2           1                10          1
#
#    EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  \
# 0               1       0         1        0              1         131160
# 1               1       0         1        6              2          41890
# 2               4       1         4        7              1         193280
# 3               1       1         3        1              1          83210
# 4               3       1         1        7              2          23420
#
#    NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0                 1.0                 11                 0                1.0
# 1                 0.0                 23                 1                6.0
# 2                 1.0                 15                 3                5.0
# 3                 3.0                 11                 3               13.0
# 4                 4.0                 12                 2                9.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      6               1                        0
# 1                      3               5                        1
# 2                      2               5                        0
# 3                      5               8                        7
# 4                      2               6                        0
#
#    YearsWithCurrManager
# 0                     0
# 1                     4
# 2                     3
# 3                     5
# 4                     4

# %% [markdown]
# # Splitting the dataset

# %%
y=data2.iloc[:,1:2]
y.head()
# Out:
#    Attrition
# 0          0
# 1          1
# 2          0
# 3          0
# 4          0

# %%
x=data2.drop(['Attrition'],axis=1)
x.head()
# Out:
#    Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51               2           2                 6          2
# 1   31               1           1                10          1
# 2   32               1           1                17          4
# 3   38               0           1                 2          5
# 4   32               2           1                10          1
#
#    EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  \
# 0               1       0         1        0              1         131160
# 1               1       0         1        6              2          41890
# 2               4       1         4        7              1         193280
# 3               1       1         3        1              1          83210
# 4               3       1         1        7              2          23420
#
#    NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0                 1.0                 11                 0                1.0
# 1                 0.0                 23                 1                6.0
# 2                 1.0                 15                 3                5.0
# 3                 3.0                 11                 3               13.0
# 4                 4.0                 12                 2                9.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      6               1                        0
# 1                      3               5                        1
# 2                      2               5                        0
# 3                      5               8                        7
# 4                      2               6                        0
#
#    YearsWithCurrManager
# 0                     0
# 1                     4
# 2                     3
# 3                     5
# 4                     4

# %% [markdown]
# # Random forest algorithm and feature importance

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(n_estimators=1000,max_features=2,oob_score=True)
rf_model.fit(x,y)
# Out:
# C:\Users\Vivek.M\anaconda3\New folder\New folder\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features=2,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print("OOB_accuracy is:",rf_model.oob_score_)
# Out:
# OOB_accuracy is: 1.0

# %%
for x,imp in zip(x,rf_model.feature_importances_):
    print(x,imp);
# Out:
# Age 0.0967779449215401
# BusinessTravel 0.027426182822360593
# Department 0.026323378739011936
# DistanceFromHome 0.07085721065437636
# Education 0.041409210294868104
# EducationField 0.04103843285072311
# Gender 0.018150099307447747
# JobLevel 0.03768947123361927
# JobRole 0.05562775728809979
# MaritalStatus 0.039228485844778685
# MonthlyIncome 0.09464182456022131
# NumCompaniesWorked 0.05572075371227731
# PercentSalaryHike 0.06537839342741548
# StockOptionLevel 0.03467423360828528
# TotalWorkingYears 0.08563488988379327
# TrainingTimesLastYear 0.04515772422197713
# YearsAtCompany 0.06757962308880272
# YearsSinceLastPromotion 0.04262774101953785
# YearsWithCurrManager 0.05405664252086393

# %% [markdown]
# # Note
#
# Age,MonthlyIncome,TotalWorkingYears are most important features and decision tree will be made based on these features only.

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
predictors=data2[['Age','MonthlyIncome','TotalWorkingYears']]
tree_model=tree.DecisionTreeClassifier(max_depth=8)
tree_model.fit(X=predictors,y=data2['Attrition'])
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=8, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# # Creating a .dot file for the obtained decision tree

# %%
with open('Dtree_attrition.dot','w')as f:
    f=tree.export_graphviz(tree_model,feature_names=['Age','MonthlyIncome','TotalWorkingYears'],out_file=f);

# %% [markdown]
# # Note
#
# There are many more leaf nodes in the obtained decision tree and only few such references are mentioned below.

# %% [markdown]
# # Leaf node inferences
#
# a) 6 Employess with Age greater than 33.5 years aud total working years greater than 39 years has attrition as YES.
#
# b) 3 Employess with Age greater than 33.5 years with total working years greater than 1.5 years but less than 39 years and having monthly income less than 10300 INR has attrition as YES.
#
# c) 30 Employess with Age greater than 33.5 years with total working years less than 1.5 years with monthly income greater than 25425 INR has attrition as NO.
#
# d) 3 Employess with Age greater than 34.5 years with total working years less than 1.5 years with monthly income less than 25425 INR has attrition as YES.
#
# e) 3 Employess with Age greater than 33.5 years but less than 34.5 years with total working years less than 1.5 years with monthly income less than 25425 INR has attrition as NO.
#
# f) 18 Employess with Age greater than 20 years but less than 33.5 years with total working years less than 1.5 years with monthly income greater than 112619 INR has attrition as NO.
#
# g) 6 Employess with Age less than 20 years with total working years less than 1.5 years with monthly income greater than 112619 INR but less than 155870 INR has attrition as NO.
#
# h) 6 Employess with Age less than 20 years with total working years less than 1.5 years with monthly income greater than 173350 INR has attrition as NO.
#
# i) 6 Employess with Age less than 20 years with total working years less than 1.5 years with monthly income greater than 155870 INR but less than 173350 INR has attrition as YES.
